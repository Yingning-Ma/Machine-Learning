# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Pokemon.csv")
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
data['Type 2'].fillna(value='None',inplace=True)
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire    None    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
data['Type 1'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Type 2'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Legendary'].value_counts().plot.bar()
print(len(data.loc[data['Legendary']==False]), len(data.loc[data['Legendary']==True]))
# Out:
# 735 65

# %%
from sklearn.model_selection import train_test_split

legendary = data.loc[data['Legendary']==True][['Type 1','Type 2','Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Legendary']]
legendary_false = data.loc[data['Legendary']==False][['Type 1','Type 2','Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Legendary']]

legendary
# Out:
#        Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 156       Ice    Flying    580   90      85      100       95      125     85
# 157  Electric    Flying    580   90      90       85      125       90    100
# 158      Fire    Flying    580   90     100       90      125       85     90
# 162   Psychic      None    680  106     110       90      154       90    130
# 163   Psychic  Fighting    780  106     190      100      154      100    130
# ..        ...       ...    ...  ...     ...      ...      ...      ...    ...
# 795      Rock     Fairy    600   50     100      150      100      150     50
# 796      Rock     Fairy    700   50     160      110      160      110    110
# 797   Psychic     Ghost    600   80     110       60      150      130     70
# 798   Psychic      Dark    680   80     160       60      170      130     80
# 799      Fire     Water    600   80     110      120      130       90     70
#
#      Legendary
# 156       True
# 157       True
# 158       True
# 162       True
# 163       True
# ..         ...
# 795       True
# 796       True
# 797       True
# 798       True
# 799       True
#
# [65 rows x 10 columns]

# %%
legendary_false
# Out:
#      Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0     Grass  Poison    318  45      49       49       65       65     45
# 1     Grass  Poison    405  60      62       63       80       80     60
# 2     Grass  Poison    525  80      82       83      100      100     80
# 3     Grass  Poison    625  80     100      123      122      120     80
# 4      Fire    None    309  39      52       43       60       50     65
# ..      ...     ...    ...  ..     ...      ...      ...      ...    ...
# 787   Ghost   Grass    494  85     100      122       58       75     54
# 788     Ice    None    304  55      69       85       32       35     28
# 789     Ice    None    514  95     117      184       44       46     28
# 790  Flying  Dragon    245  40      30       35       45       40     55
# 791  Flying  Dragon    535  85      70       80       97       80    123
#
#      Legendary
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 787      False
# 788      False
# 789      False
# 790      False
# 791      False
#
# [735 rows x 10 columns]

# %%
legendary_false_under = legendary_false.sample(200)
datasets = pd.concat([legendary, legendary_false_under])
datasets = pd.get_dummies(datasets)
datasets
# Out:
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary  \
# 156    580   90      85      100       95      125     85       True
# 157    580   90      90       85      125       90    100       True
# 158    580   90     100       90      125       85     90       True
# 162    680  106     110       90      154       90    130       True
# 163    780  106     190      100      154      100    130       True
# ..     ...  ...     ...      ...      ...      ...    ...        ...
# 766    362   58      89       77       45       45     48      False
# 574    316   50      53       48       53       48     64      False
# 177    262   60      30       30       36       56     50      False
# 503    300   48      61       40       61       40     50      False
# 320    237   72      60       30       20       30     25      False
#
#      Type 1_Bug  Type 1_Dark  ...  Type 2_Grass  Type 2_Ground  Type 2_Ice  \
# 156           0            0  ...             0              0           0
# 157           0            0  ...             0              0           0
# 158           0            0  ...             0              0           0
# 162           0            0  ...             0              0           0
# 163           0            0  ...             0              0           0
# ..          ...          ...  ...           ...            ...         ...
# 766           0            0  ...             0              0           0
# 574           0            0  ...             0              0           0
# 177           0            0  ...             0              0           0
# 503           0            0  ...             0              0           0
# 320           0            0  ...             0              0           0
#
#      Type 2_None  Type 2_Normal  Type 2_Poison  Type 2_Psychic  Type 2_Rock  \
# 156            0              0              0               0            0
# 157            0              0              0               0            0
# 158            0              0              0               0            0
# 162            1              0              0               0            0
# 163            0              0              0               0            0
# ..           ...            ...            ...             ...          ...
# 766            0              0              0               0            0
# 574            1              0              0               0            0
# 177            0              0              0               0            0
# 503            0              0              0               0            0
# 320            1              0              0               0            0
#
#      Type 2_Steel  Type 2_Water
# 156             0             0
# 157             0             0
# 158             0             0
# 162             0             0
# 163             0             0
# ..            ...           ...
# 766             0             0
# 574             0             0
# 177             0             0
# 503             0             0
# 320             0             0
#
# [265 rows x 45 columns]

# %%
labels = datasets['Legendary']
datasets = datasets.drop('Legendary', 1)
datasets.shape
# Out:
# /var/folders/hb/j7hf27dn2y7gwbtj3vczf0600000gn/T/ipykernel_23744/3833309962.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   datasets = datasets.drop('Legendary', 1)
# (265, 44)

# %%
training_data, test_data, training_label, test_label = train_test_split(datasets, labels, random_state = 22, test_size = 0.3)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=15,sampling_strategy= 1.0)
training_data, training_label = smote.fit_resample(training_data, training_label)
training_data.shape
# Out:
# (276, 44)

# %%
training_label.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
from sklearn import tree
#clf = tree.DecisionTreeClassifier(max_depth=10,min_samples_leaf=2,min_impurity_decrease=0.1, class_weight = "balanced")
clf = tree.DecisionTreeClassifier()
clf.fit(training_data, training_label)
test_pred_tree =  clf.predict(test_data)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_label, test_pred_tree)
# Out:
# 0.9625

# %%
from sklearn.ensemble import RandomForestClassifier 
model = RandomForestClassifier(n_estimators=100,max_depth=)
model.fit(training_data, training_label)
# Out:
# RandomForestClassifier(max_depth=7)

# %%
test_pred =  model.predict(test_data)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(test_label, test_pred)
# Out:
# 0.9875

# %%
features = pd.DataFrame({'feature':training_data.columns,'importance':np.round(model.feature_importances_,3)})
features = features.sort_values('importance',ascending=False)
features
# Out:
#             feature  importance
# 0             Total       0.299
# 4           Sp. Atk       0.131
# 1                HP       0.129
# 6             Speed       0.122
# 5           Sp. Def       0.102
# 2            Attack       0.068
# 3           Defense       0.050
# 37      Type 2_None       0.021
# 24     Type 1_Water       0.014
# 16     Type 1_Grass       0.010
# 35    Type 2_Ground       0.007
# 19    Type 1_Normal       0.005
# 29     Type 2_Fairy       0.004
# 12  Type 1_Fighting       0.004
# 21   Type 1_Psychic       0.004
# 39    Type 2_Poison       0.004
# 13      Type 1_Fire       0.003
# 23     Type 1_Steel       0.003
# 26      Type 2_Dark       0.002
# 40   Type 2_Psychic       0.002
# 36       Type 2_Ice       0.002
# 22      Type 1_Rock       0.002
# 7        Type 1_Bug       0.002
# 8       Type 1_Dark       0.002
# 9     Type 1_Dragon       0.002
# 20    Type 1_Poison       0.001
# 32    Type 2_Flying       0.001
# 42     Type 2_Steel       0.001
# 41      Type 2_Rock       0.001
# 10  Type 1_Electric       0.001
# 18       Type 1_Ice       0.001
# 33     Type 2_Ghost       0.001
# 30  Type 2_Fighting       0.001
# 27    Type 2_Dragon       0.001
# 17    Type 1_Ground       0.001
# 43     Type 2_Water       0.001
# 31      Type 2_Fire       0.000
# 34     Type 2_Grass       0.000
# 11     Type 1_Fairy       0.000
# 14    Type 1_Flying       0.000
# 28  Type 2_Electric       0.000
# 38    Type 2_Normal       0.000
# 15     Type 1_Ghost       0.000
# 25       Type 2_Bug       0.000

# %%
features = features.set_index('feature')

# %%
plot = features.plot.pie(y='importance', figsize=(15, 15))
